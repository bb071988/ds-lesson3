# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import re

# %%
def IR_Flag(rate):
    if rate > .12:
        return True
    else:
        return False

# %%
def num_strip_rt(data):
    if '%' in data:
        data = data.rstrip('%')
        
    if "." in data:
        data = float(data)/100
        
    return data

# %%
def get_int_from_text(data):
#     data = re.search('[0-9]*', data).group(0)
    data = re.findall('[0-9]+', data) # produces a 1 item list
    
#     print("data is type {}".format(type(data)))
    
#     data = [x for x in data if x != '']

    try:
        return data[0]
    except: 
        return len(data)

# %%
# get loandata
raw_data = pd.read_csv('https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv')

# %%
#ask Kyle why this runs so slow

raw_data['Debt.To.Income.Ratio'] = [num_strip_rt(data) for index, data in raw_data['Debt.To.Income.Ratio'].iteritems()]

# %%
raw_data['Interest.Rate'] = [num_strip_rt(data) for index, data in raw_data['Interest.Rate'].iteritems()]

# %%
raw_data['Loan.Length'] = [get_int_from_text(data) for index, data in raw_data['Loan.Length'].iteritems()]

# %%
raw_data['Employment.Length'] = [get_int_from_text(data) for index, data in raw_data['Employment.Length'].iteritems()]

# %%
raw_data
# Out:
#         Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  \
# 81174              20000                    20000.00         0.0890
# 99592              19200                    19200.00         0.1212
# 80059              35000                    35000.00         0.2198
# 15825              10000                     9975.00         0.0999
# 33182              12000                    12000.00         0.1171
# 62403               6000                     6000.00         0.1531
# 48808              10000                    10000.00         0.0790
# 22090              33500                    33450.00         0.1714
# 76404              14675                    14675.00         0.1433
# 15867               7000                     7000.00         0.0691
# 94971               2000                     2000.00         0.1972
# 36911              10625                    10625.00         0.1427
# 41200              28000                    27975.00         0.2167
# 83869              35000                    34950.00         0.0890
# 53853               9600                     9600.00         0.0762
# 21399              25000                    24975.00         0.1565
# 62127              10000                    10000.00         0.1212
# 23446              14000                    13900.25         0.1037
# 44987              10000                    10000.00         0.0976
# 17977               5200                     5175.00         0.0999
# 86099              22000                    21975.00         0.2198
# 99483              30000                    30000.00         0.1905
# 28798               6500                     6500.00         0.1799
# 24168              17400                    17400.00         0.1199
# 10356               4000                     4000.00         0.1682
# 46027               7200                     7200.00         0.0790
# 2238                8000                     8000.00         0.1442
# 65278               8000                     8000.00         0.1531
# 4227                3000                     3000.00         0.0859
# 50182              14500                    14500.00         0.0790
# ...                  ...                         ...            ...
# 84265              20000                    20000.00         0.2295
# 80231              19000                    19000.00         0.0790
# 49533              17300                    17250.00         0.2245
# 102514              7000                      711.54         0.1513
# 78618               7200                     7200.00         0.1875
# 86953              10000                    10000.00         0.1409
# 80129               4000                     3925.00         0.1409
# 85216              17500                    17500.00         0.0890
# 38247              20000                    20000.00         0.1171
# 91245              16200                    16200.00         0.1580
# 53041              10000                    10000.00         0.0603
# 63051              27000                    27000.00         0.0662
# 14446               4500                     4475.00         0.0751
# 68628              15875                    15875.00         0.1433
# 98758              15000                    15000.00         0.1016
# 13070              25000                    24950.00         0.1075
# 45836               7000                     7000.00         0.1727
# 52330              15000                    15000.00         0.1999
# 48243              17000                    17000.00         0.1581
# 63256              19075                    19075.00         0.1875
# 42124              10000                    10000.00         0.1171
# 78043               8475                     8475.00         0.0762
# 925                 6400                     6350.00         0.1008
# 74047              30000                    30000.00         0.2328
# 49957              24000                    23975.00         0.1465
# 23735              30000                    29950.00         0.1677
# 65882              16000                    16000.00         0.1409
# 55610              10000                    10000.00         0.1399
# 38576               6000                     6000.00         0.1242
# 3116                9000                     5242.75         0.1379
#
#        Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 81174           36  debt_consolidation                0.149    SC
# 99592           36  debt_consolidation               0.2836    TX
# 80059           60  debt_consolidation               0.2381    CA
# 15825           36  debt_consolidation                0.143    KS
# 33182           36         credit_card               0.1878    NJ
# 62403           36               other               0.2005    CT
# 48808           36  debt_consolidation               0.2609    MA
# 22090           60         credit_card                0.147    LA
# 76404           36         credit_card               0.2692    CA
# 15867           36         credit_card                0.071    CA
# 94971           36              moving               0.1029    FL
# 36911           36  debt_consolidation               0.1254    CA
# 41200           60  debt_consolidation               0.1307    CT
# 83869           36  debt_consolidation               0.2046    CT
# 53853           36  debt_consolidation               0.0345    DC
# 21399           60  debt_consolidation               0.2199    CA
# 62127           36  debt_consolidation               0.1772    CA
# 23446           60  debt_consolidation               0.1195    OH
# 44987           36         credit_card               0.0713    FL
# 17977           60  debt_consolidation               0.1029    AL
# 86099           36  debt_consolidation               0.1119    TX
# 99483           60         credit_card               0.2125    FL
# 28798           60                 car               0.1963    FL
# 24168           36         credit_card               0.1247    AZ
# 10356           60            vacation               0.1371    GA
# 46027           36  debt_consolidation               0.2482    TX
# 2238            36  debt_consolidation               0.2463    MA
# 65278           36  debt_consolidation               0.1546    CA
# 4227            36               other               0.0372    MA
# 50182           36  debt_consolidation               0.0485    GA
# ...            ...                 ...                  ...   ...
# 84265           60  debt_consolidation                0.071    NJ
# 80231           36  debt_consolidation               0.0976    RI
# 49533           60             wedding               0.0358    PA
# 102514          36      major_purchase               0.1891    CO
# 78618           36  debt_consolidation               0.1621    MI
# 86953           36      major_purchase               0.0971    CO
# 80129           36         credit_card               0.1227    FL
# 85216           36  debt_consolidation               0.1094    UT
# 38247           36         credit_card               0.0958    SD
# 91245           60  debt_consolidation               0.0792    PA
# 53041           36      small_business               0.1303    FL
# 63051           36  debt_consolidation               0.1221    OH
# 14446           36      small_business               0.2027    VA
# 68628           36      small_business               0.1744    MD
# 98758           36         credit_card               0.2828    OH
# 13070           36  debt_consolidation               0.2048    OR
# 45836           36               other               0.1838    NY
# 52330           36             wedding               0.1805    CA
# 48243           36  debt_consolidation               0.1701    CO
# 63256           36  debt_consolidation               0.1523    NY
# 42124           36  debt_consolidation                0.084    CA
# 78043           36  debt_consolidation               0.1588    CA
# 925             36  debt_consolidation               0.0811    NJ
# 74047           60               other                0.121    IL
# 49957           36  debt_consolidation               0.1529    WA
# 23735           60  debt_consolidation               0.1923    NY
# 65882           60    home_improvement               0.2154    MD
# 55610           36  debt_consolidation               0.0489    PA
# 38576           36      major_purchase               0.1666    NJ
# 3116            36  debt_consolidation               0.0676    NY
#
#        Home.Ownership  Monthly.Income FICO.Range  Open.CREDIT.Lines  \
# 81174        MORTGAGE         6541.67    735-739                 14
# 99592        MORTGAGE         4583.33    715-719                 12
# 80059        MORTGAGE        11500.00    690-694                 14
# 15825        MORTGAGE         3833.33    695-699                 10
# 33182            RENT         3195.00    695-699                 11
# 62403             OWN         4891.67    670-674                 17
# 48808            RENT         2916.67    720-724                 10
# 22090        MORTGAGE        13863.42    705-709                 12
# 76404            RENT         3150.00    685-689                  9
# 15867            RENT         5000.00    715-719                  8
# 94971            RENT         3575.00    670-674                 10
# 36911        MORTGAGE         4250.00    665-669                 14
# 41200        MORTGAGE        14166.67    670-674                 12
# 83869            RENT         9166.67    735-739                 19
# 53853            RENT        11250.00    725-729                 13
# 21399            RENT         5416.67    730-734                  6
# 62127            RENT         9000.00    695-699                 18
# 23446            RENT         4333.33    740-744                  6
# 44987            RENT         2733.33    730-734                  7
# 17977        MORTGAGE         3750.00    760-764                 10
# 86099        MORTGAGE         6666.67    665-669                  9
# 99483        MORTGAGE         6250.00    695-699                 12
# 28798            RENT         4100.00    665-669                 11
# 24168            RENT         6833.33    695-699                  7
# 10356        MORTGAGE         4500.00    670-674                  5
# 46027            RENT         5416.67    705-709                  8
# 2238             RENT         2964.17    675-679                  9
# 65278        MORTGAGE         2916.67    675-679                 13
# 4227         MORTGAGE         4167.00    765-769                  4
# 50182        MORTGAGE         3958.33    760-764                  4
# ...               ...             ...        ...                ...
# 84265            RENT         6750.00    665-669                  6
# 80231        MORTGAGE         5166.67    770-774                 18
# 49533        MORTGAGE         5500.00    685-689                 11
# 102514       MORTGAGE         3833.00    650-654                 13
# 78618            RENT         8333.33    660-664                  8
# 86953            RENT         4583.33    675-679                  6
# 80129        MORTGAGE         8583.33    675-679                  9
# 85216        MORTGAGE        25000.00    730-734                  9
# 38247        MORTGAGE         5416.67    725-729                 12
# 91245        MORTGAGE         4833.33    680-684                 12
# 53041            RENT         5000.00    760-764                  8
# 63051        MORTGAGE         9250.00    810-814                 12
# 14446        MORTGAGE         7075.50    720-724                 15
# 68628        MORTGAGE         3416.67    675-679                 11
# 98758        MORTGAGE         6666.67    690-694                 15
# 38247                  4
# 91245                 10
# 53041                  2
# 63051                  5
# 14446                 10
# 68628                  2
# 98758                 10
# 13070                  6
# 45836                  3
# 52330                  2
# 48243                  6
# 63256                 10
# 42124                  3
# 78043                  0
# 925                   10
# 74047                 10
# 49957                  5
# 23735                  8
# 65882                 10
# 55610                 10
# 38576                  5
# 3116                  10
#
# [2500 rows x 14 columns]

# %%
type(raw_data['Loan.Length'][:1])

# %%
def fix_data(raw_data):
       
    # clean interest rate using regex - ability to replace so df objects are mutable
    raw_data['Interest.Rate'] = [float(re.search('^[0-9]*.[0-9]*',loan).group(0))/100 for loan in raw_data['Interest.Rate']]

    # clean fico range and get score 
    raw_data['FICO.Score'] = map(lambda x: int(x.split('-')[0]), raw_data['FICO.Range'])
    
    # clean loan length
    raw_data['Loan.Length'] = map(lambda x: int(x.split()[0]), raw_data['Loan.Length'])
    
    # clean debt to income ratio
    raw_data['Debt.To.Income.Ratio'] = [float(re.search('^[0-9]*.[0-9]*',loan).group(0))/100 for loan in raw_data['Debt.To.Income.Ratio']]
    
    # add rate flag
    loan_data['IR_TF'] = [IR_Flag(rate) for index, rate in loan_data['Interest.Rate'].iteritems()]
    
    # add constant
    loan_data['Constant'] = [1 for row in loan_data.iterrows()]
    
    return raw_data

# %%
raw_data.head()

# %%
 # clean debt to income ratio
raw_data['Debt.To.Income.Ratio'] = [float(re.search('^[0-9]*.[0-9]*',loan).group(0) for loan in raw_data['Debt.To.Income.Ratio']]

# %%
raw_data.head()

# %%
raw_data.head()

# %%
loan_data = fix_data(raw_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7298b28c5bdf> in <module>()
# ----> 1 loan_data = fix_data(raw_data)
#
# <ipython-input-22-95499c3a2d41> in fix_data(raw_data)
#      11
#      12     # clean debt to income ratio
# ---> 13     raw_data['Debt.To.Income.Ratio'] = [float(re.search('^[0-9]*.[0-9]*',loan).group(0))/100 for loan in raw_data['Debt.To.Income.Ratio']]
#      14
#      15
#
# ValueError: invalid literal for float(): 4%

# %%
raw_data.head()

# %%
ind_vars = list(loan_data.columns.values)

# %%
ind_vars.remove('Interest.Rate')

# %%
ind_vars.remove('IR_TF')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-19b86cb9f1f7> in <module>()
# ----> 1 ind_vars.remove('IR_TF')
#       2 ind_vars.remove('Constant')
#
# ValueError: list.remove(x): x not in list

# %%
ind_vars.remove('Constant')

# %%
ind_vars
# Out:
# ['Amount.Requested',
#  'Amount.Funded.By.Investors',
#  'Loan.Length',
#  'Loan.Purpose',
#  'Debt.To.Income.Ratio',
#  'State',
#  'Home.Ownership',
#  'Monthly.Income',
#  'FICO.Range',
#  'Open.CREDIT.Lines',
#  'Revolving.CREDIT.Balance',
#  'Inquiries.in.the.Last.6.Months',
#  'Employment.Length',
#  'FICO.Score',
#  'Constant']
